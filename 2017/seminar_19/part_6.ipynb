# %% [markdown]
# # 6 RNN for language modeling

# %%
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
import numpy as np
import random
import sys
import io
# Out:
# /opt/anaconda3/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
text = open('shakespeare.txt', 'r').read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# corpus length: 5342761
# total chars: 54

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in tqdm(range(0, len(text) - maxlen, step)):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# 100%|██████████| 1780907/1780907 [00:01<00:00, 979978.46it/s]
# nb sequences: 1780907

# %%
# Vectorization
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in tqdm(enumerate(sentences)):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 1780907it [00:27, 64377.77it/s]

# %%
X.shape
# Out:
# (1780907, 40, 54)

# %%
y.shape
# Out:
# (1780907, 54)

# %%
# build the model: a single LSTM
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               93696
# _________________________________________________________________
# dense_1 (Dense)              (None, 54)                6966
# _________________________________________________________________
# activation_1 (Activation)    (None, 54)                0
# =================================================================
# Total params: 100,662
# Trainable params: 100,662
# Non-trainable params: 0
# _________________________________________________________________

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)

    generated = ''
    sentence = text[start_index: start_index + maxlen]
    generated += sentence
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)

    for i in range(200):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(X, y,
          batch_size=4096,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Epoch 1/60
# 1780907/1780907 [==============================] - 69s 38us/step - loss: 2.1090 - acc: 0.3829
#
# ----- Generating text after Epoch: 0
# ----- Generating with seed: "w!
# 	that pure congealed white, high taur"
# w!
# 	that pure congealed white, high taurs to tith.
#
# casunol	again, i by all, befied.
#
# flord	this have this ever hiadtencud,
# 	i be could reath, shall must forty me; to detwo
# 	deeptheds stret elone wonds, aw you imop of a boge:
# 	gimative, how
# Epoch 2/60
# 1780907/1780907 [==============================] - 63s 35us/step - loss: 1.6357 - acc: 0.5039
#
# ----- Generating text after Epoch: 1
# ----- Generating with seed: "wn her consecrated wall,
# and by their mo"
# wn her consecrated wall,
# and by their most up your yiched hand and see-but curming a pliused time,
# 	at-aspies of but be drem, 'tis no more piege;
# 	no were in this recrest on appearus
# 	lain aim quoth no lovent pard'd aymen.
#
# calumand	how no
# Epoch 3/60
# 1780907/1780907 [==============================] - 61s 34us/step - loss: 1.5333 - acc: 0.5315
#
# ----- Generating text after Epoch: 2
# ----- Generating with seed: " mine earnest words;
# 	mine eyes should s"
#  mine earnest words;
# 	mine eyes should see his rold--
#
# ommissave	marcal upon our friends word fleshing have,
# 	diend of at her theer's; master him.
#
# romion	what, if sayed causirance of the smarness;
# 	and i what is to-discerse and parence
# 	st
# Epoch 4/60
# 1780907/1780907 [==============================] - 62s 35us/step - loss: 1.4859 - acc: 0.5443
#
# ----- Generating text after Epoch: 3
# ----- Generating with seed: "us
# 	adore our errors; laugh at's, while "
# us
# 	adore our errors; laugh at's, while now?
#
# citizens	draw father! that his better by this;
# 	that will not never
# takensirement	corrors.
#
# 	[we field in player claim. by ridons of our hands.
#
# sir woll hazry	the rest y die you our cup.
#
# pease
# Epoch 5/60
# 1780907/1780907 [==============================] - 61s 34us/step - loss: 1.4568 - acc: 0.5517
#
# ----- Generating text after Epoch: 4
# ----- Generating with seed: "o see such a sight, it well
# 	becomes the"
# o see such a sight, it well
# 	becomes the thoughts it such a hand.'
# 	word, i did procoud, you had thy brother?
#
# slanme witchmuntit	franes, if you hath defipon's might so idle.
#
# gublersia	you have hargard yet; where will i plimpation'd
# 	meed
# Epoch 6/60
# 1780907/1780907 [==============================] - 61s 34us/step - loss: 1.4369 - acc: 0.5572
#
# ----- Generating text after Epoch: 5
# ----- Generating with seed: "	as my two brothers, happy! but most mis"
# 	as my two brothers, happy! but most misshir.
# 	many i besneatenced sir underswayn'd	thou art vale, ay all thousand wise his foil,
# 	this silent inquiotity messengerspur; for she
# 	i make him to our other's base in quains
# 	i can kill'des you,
# Epoch 7/60
# 1780907/1780907 [==============================] - 60s 34us/step - loss: 1.4215 - acc: 0.5606
#
# ----- Generating text after Epoch: 6
# ----- Generating with seed: "	let her lie still and dream.
#
# 	[knocks]"
# 	let her lie still and dream.
#
# 	[knocks]
#
# uldemus	is, 'le getter's to you, my hand, your bloody beingly soldiers,
# 	to sempraace to a countrague of eastly.
#
# gloucester	he is, an away. and so inajulate wail:
# 	not in fansidon to lost sun the e
# Epoch 8/60
# 1780907/1780907 [==============================] - 59s 33us/step - loss: 1.4101 - acc: 0.5639
#
# ----- Generating text after Epoch: 7
# ----- Generating with seed: "mple true judgment; or would you have me"
# mple true judgment; or would you have me' him.
#
# 	[things right, beggar our queen's dotwish,
# 	which captains twice eard, but become our give somere
# conquest, and the fears with signife confidence.
# 	by hands a time brother calpers undeed.
# 	i
# Epoch 9/60
# 1780907/1780907 [==============================] - 60s 33us/step - loss: 1.4007 - acc: 0.5660
#
# ----- Generating text after Epoch: 8
# ----- Generating with seed: " pick'd out: for, i am sure,
# 	though you"
#  pick'd out: for, i am sure,
# 	though yours, we and the head of idiconce,
# 	when o this? that i'll spoke upon seen mine.
#
# 	[enter matie and terms again]
#
# 	i, with the beggaties; charies up her:
# 	and where carr thou but the pirely belied
# 	that
# Epoch 10/60
# 1780907/1780907 [==============================] - 60s 34us/step - loss: 1.3931 - acc: 0.5679
#
# ----- Generating text after Epoch: 9
# ----- Generating with seed: "sfaction do i crave,
# 	but only, with you"
# sfaction do i crave,
# 	but only, with your great bridaded,   french dorned of
# 	one's knift barrandess
# 	of straiter he have i subject that men,
# 	and i'll so think you mund?
#
# doe bausind	well make-frum he in the resolus crest.
#
# prince secarilo
# Epoch 11/60
# 1780907/1780907 [==============================] - 59s 33us/step - loss: 1.3864 - acc: 0.5697
#
# ----- Generating text after Epoch: 10
# ----- Generating with seed: "wer.
#
# vernon	of the white-rose or york f"
# wer.
#
# vernon	of the white-rose or york fer sacred call's glods. for
# /opt/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: RuntimeWarning: divide by zero encountered in log
# upon him?
#
# dromio orialice	yet nurs. master, let me came your spite to leave him to wherelous,
# 	are-virghace. little stone, that knock'd one perperercable: only this call
#
# Epoch 12/60
# 1780907/1780907 [==============================] - 60s 34us/step - loss: 1.3807 - acc: 0.5706
#
# ----- Generating text after Epoch: 11
# ----- Generating with seed: "
# 	down indirectly to the jew's house.
#
# g"
#
# 	down indirectly to the jew's house.
#
# gloucester	i pay the woels' quiet heralt. give me noble
# 	be roman
# 	simplingession the tailors are in;
# 	commands for face. hear my heart than thou,
# 	so, would weep them and meedles? this know
# 	this moon
# Epoch 13/60
# 1780907/1780907 [==============================] - 60s 34us/step - loss: 1.3758 - acc: 0.5722
#
# ----- Generating text after Epoch: 12
# ----- Generating with seed: "n the banquet quickly; wine enough
# 	cleo"
# n the banquet quickly; wine enough
# 	cleon much respectus
# hadly-bidful	a sin. was he repent these of a foos all'd the
# 	john of the women or dived of those battles win most armiss:
# 	he had reposuint and desires, and hath weep'd.
# 	that, i must
# Epoch 14/60
# 1780907/1780907 [==============================] - 60s 34us/step - loss: 1.3712 - acc: 0.5733
#
# ----- Generating text after Epoch: 13
# ----- Generating with seed: "alamity.
# 	like an unseasonable stormy da"
# alamity.
# 	like an unseasonable stormy dance.
#
# cleopatra	passe belved, you the leasus and service thee
# 	who hear money is a thrice perfers,
# 	outward hences, river upon and marry to
# 	swore to be the crask belfal?
#
# telluutes	sir, when nothing
# Epoch 15/60
# 1780907/1780907 [==============================] - 60s 34us/step - loss: 1.3676 - acc: 0.5741
#
# ----- Generating text after Epoch: 14
# ----- Generating with seed: "d over
# 	in states unborn and accents yet"
# d over
# 	in states unborn and accents yet. the heart is dew he
# 	seect with fellanker boug! my mower write,
# 	in courtore have dond to confort against your ophels;
# 	not hill. i swees not say my painting and lebove ere welcome
# 	unproward hath h
# Epoch 16/60
# 1780907/1780907 [==============================] - 60s 34us/step - loss: 1.3654 - acc: 0.5749
#
# ----- Generating text after Epoch: 15
# ----- Generating with seed: "rland	hold, clifford! do not honour him "
# rland	hold, clifford! do not honour him to so?
#
# volot	but, grace, you shall trust me my pain, did
# 	say, to follow'st believed of their censed of walk,
# to prisoners of gracely they bear thee
# 	doth loves now.
#
# king lear	he; i look your gill--
# Epoch 17/60
# 1780907/1780907 [==============================] - 59s 33us/step - loss: 1.3629 - acc: 0.5753
#
# ----- Generating text after Epoch: 16
# ----- Generating with seed: "ery, to take upon you another man's name"
# ery, to take upon you another man's named storm'd:
# 	lay all same chaste and by the provice of the sech.
#
# lafeu	tell mine. never well make me not pear confale!
# 	and pinche hold: leas my mind's beside.
#
# iago	say does knows well; who have hang
# Epoch 18/60
# 1780907/1780907 [==============================] - 59s 33us/step - loss: 1.3588 - acc: 0.5763
#
# ----- Generating text after Epoch: 17
# ----- Generating with seed: "h bound to you for't: i am one that
# 	had"
# h bound to you for't: i am one that
# 	had too such a wounds to he, with grace,
# 	to his wonders more thy poor face to the
# 	miseveror-sums. canso, what couldst not for it?
#
# mark antony	i'll have charge's shrinken: allow, of lords.
#
# 	[aside of
# Epoch 19/60
# 1780907/1780907 [==============================] - 61s 34us/step - loss: 1.3558 - acc: 0.5772
#
# ----- Generating text after Epoch: 18
# ----- Generating with seed: " the morning,
# 	and put thy fortune to th"
#  the morning,
# 	and put thy fortune to there doth in distrains.
# 	you abboth more some from here and croste a
# 	best to compited through still; thou that
# 	but love brutus to clook. go, shall i come!
# 	who, bear she begin to all the engliss,
# 	at
# Epoch 20/60
# 1780907/1780907 [==============================] - 60s 34us/step - loss: 1.3542 - acc: 0.5775
#
# ----- Generating text after Epoch: 19
# ----- Generating with seed: "e church. i have dogged him, like his
# 	m"
# e church. i have dogged him, like his
# 	mind please their kneels? that, my lordnigerous is,
# 	looks, a mercyred, lyssan letter hulby.
#
# king edward vuct	hard, but sirth, set buy my dougboy messumind,
# 	none tybades, well]
#
# kathanio	tall not so
# Epoch 21/60
# 1780907/1780907 [==============================] - 59s 33us/step - loss: 1.3527 - acc: 0.5780
#
# ----- Generating text after Epoch: 20
# ----- Generating with seed: "lord!
#
# othello	who's there?
#
# emilia	[wit"
# lord!
#
# othello	who's there?
#
# emilia	[within, to the chamberlain] ' but what will not.
#
# hamlet	i am:
# 	here comes it me letters of clothandle;
# 	he'll be duint-witedhy heart! eates woo with all berence.
#
# mark antony	syracust you are lips: so.
# Epoch 22/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3487 - acc: 0.5785
#
# ----- Generating text after Epoch: 21
# ----- Generating with seed: "ne part of
# 	our roman power: your lord a"
# ne part of
# 	our roman power: your lord awake,--
#
# diom of shalan	i'll revermness,
# 	our footed-hour of this vouch-opition of those the
# 	latethy and prayers, herable such there which seem here's not i a wostepoling.
#
# lords	i even have your com
# Epoch 23/60
# 1780907/1780907 [==============================] - 58s 32us/step - loss: 1.3482 - acc: 0.5787
#
# ----- Generating text after Epoch: 22
# ----- Generating with seed: "ter coriolanus, menenius, and cominius,
# "
# ter coriolanus, menenius, and cominius,
# 	hear something, herence, at your brother,
# 	why i studity.
#
# aroned	here is he cannot crester the name of liontly,
# 	and to we hear
#
#
# rendops. but sould me won. i have messent to lime to rest;
# 	shall de
# Epoch 24/60
# 1780907/1780907 [==============================] - 58s 33us/step - loss: 1.3455 - acc: 0.5794
#
# ----- Generating text after Epoch: 23
# ----- Generating with seed: " humour of bread and cheese,
# 	and there'"
#  humour of bread and cheese,
# 	and there's o'er pleased downsised
# 	promosted a thanks;
# a clood, allowon acquainted fox one head;
# eines the mischief or two, thy name of neighbour that
# 	twofe upon me! blush to knitch for my other
# 	that hurt, a
# Epoch 25/60
# 1780907/1780907 [==============================] - 59s 33us/step - loss: 1.3442 - acc: 0.5797
#
# ----- Generating text after Epoch: 24
# ----- Generating with seed: "t me to the heart.
#
# 	[enter the boy with"
# t me to the heart.
#
# 	[enter the boy with sorve, sigring within he rome
# 	why stuff this well had in cousin the neck-bodned confirmeth weed
# 	in foul dead.
#
# william	now your son. thankness do with mine.
#
# 	[knockis and unwix	|
# 	pray,
# 	and come
# Epoch 26/60
# 1780907/1780907 [==============================] - 61s 34us/step - loss: 1.3424 - acc: 0.5803
#
# ----- Generating text after Epoch: 25
# ----- Generating with seed: "away with the rest.
#
# caliban	i will have"
# away with the rest.
#
# caliban	i will have mess: be no 'incerian?
#
# to claudio	no my nobless, some of all disvenict,
# 	staive with double and reportful many: look
# 	that to come by heavy of soonesty of
# 	steale to breeds you told you bannas?
# 	fin
# Epoch 27/60
# 1780907/1780907 [==============================] - 61s 35us/step - loss: 1.3407 - acc: 0.5808
#
# ----- Generating text after Epoch: 26
# ----- Generating with seed: "y! though parting be a fretful corrosive"
# y! though parting be a fretful corrosive and muster:
# 	o march in.
#
# recas	lysino o' this thought, put you now: for to
# 	stratished; and seal here.
#
# cloten	worge to he is this bride.
#
# parictiver	and to lay my father; sir never or be maniet
# 	th
# Epoch 28/60
# 1780907/1780907 [==============================] - 60s 34us/step - loss: 1.3393 - acc: 0.5811
#
# ----- Generating text after Epoch: 27
# ----- Generating with seed: "o it.
#
# 	[re-enter macduff]
#
# macduff	o ho"
# o it.
#
# 	[re-enter macduff]
#
# macduff	o honour, servingment.
#
# antipholus
# of ephesus	,ifial; if ever leave his frohting that is fray'd to return'd,
# 	and i'll tell me wronge.
#
# apemas	our chance of some twoillow mettle.
#
# julia	if you grant of a
# Epoch 29/60
# 1780907/1780907 [==============================] - 60s 34us/step - loss: 1.3377 - acc: 0.5815
#
# ----- Generating text after Epoch: 28
# ----- Generating with seed: "weather in us all, good sir,
# 	when you a"
# weather in us all, good sir,
# 	when you are engling hath money doth
# 	priestery of grave to beaten his drops,
# 	this strait that but unnothy not all
# 	many and been furw. at flies his orst more and
# 	heart you with an other indireus, that in
# 	th
# Epoch 30/60
# 1780907/1780907 [==============================] - 61s 34us/step - loss: 1.3367 - acc: 0.5817
#
# ----- Generating text after Epoch: 29
# ----- Generating with seed: "r accommodate
# 	his master thus.
#
# king le"
# r accommodate
# 	his master thus.
#
# king lear	in up, occas, what mons.
#
# troilus	go, no fortune, then fly as't part, and larguland.
# 	why should say, for my as should it, good man. i think it,
# 	speak with hand. and, my liege, i troinity.
#
# prince
# Epoch 31/60
# 1780907/1780907 [==============================] - 60s 34us/step - loss: 1.3355 - acc: 0.5820
#
# ----- Generating text after Epoch: 30
# ----- Generating with seed: " are paid too much; purse and brain
# 	bot"
#  are paid too much; purse and brain
# 	both a mairle reverend marriage her matter
# 	else we
# differed	meder of it.
#
# 	[florenio]
#
#
#
# 	jullow'--
#
# 	[flourish, come, sick i am more vowasony
# 	you have never now i were bonish!--flies my
# 	tinan, and re
# Epoch 32/60
# 1780907/1780907 [==============================] - 59s 33us/step - loss: 1.3345 - acc: 0.5822
#
# ----- Generating text after Epoch: 31
# ----- Generating with seed: " leave here, gentlemen.
#
# posthumus leona"
#  leave here, gentlemen.
#
# posthumus leonat, senatorsius, and field is, fright,
# 	to satie lofe spite?
#
# dumain	autoter!
#
# hamler	thy unworthous gentleman, cities.
#
# petruchio	with such temps should assurd'd; showor she
# 	is ever lord less hate, a
# Epoch 33/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3337 - acc: 0.5825
#
# ----- Generating text after Epoch: 32
# ----- Generating with seed: "ed;
# 	this field-bed is too cold for me t"
# ed;
# 	this field-bed is too cold for me to our
# 	thy grecial often threely else, humphit,
# 	that you shall be your king! first could serve in tay.
#
# 	[exit]
#
# viola	for my love, it is the inteit.
#
# 	[exit]
#
# widow	it is a strike of me, sociotin:
#
# Epoch 34/60
# 1780907/1780907 [==============================] - 59s 33us/step - loss: 1.3321 - acc: 0.5827
#
# ----- Generating text after Epoch: 33
# ----- Generating with seed: "ehood,
# 	call me before the exactest audi"
# ehood,
# 	call me before the exactest audity,
# 	that it said; besith all a kind humourty:
# 	and have no man five cursed believed shall sweet liver,
# like us gone wealthty are it wert will rans me.
#
# page	who's not; and said hector, but if vile ma
# Epoch 35/60
# 1780907/1780907 [==============================] - 58s 32us/step - loss: 1.3310 - acc: 0.5832
#
# ----- Generating text after Epoch: 34
# ----- Generating with seed: "tire	attire, head-dress
# tire	to tear as "
# tire	attire, head-dress
# tire	to tear as died: 'tis wits and look,
# 	in every smoose she say in brilage the mind.
#
# duke priteiti	she that did look on thy unto tabourder.
#
# second citizen	sir john, my lord of whorefores something fair
# 	hath har
# Epoch 36/60
# 1780907/1780907 [==============================] - 58s 32us/step - loss: 1.3303 - acc: 0.5831
#
# ----- Generating text after Epoch: 35
# ----- Generating with seed: "t, speak, and
# 	move under the influence "
# t, speak, and
# 	move under the influence of your faith,
# 	myself, home my cruck'd is?
#
# balters	how goes on
# 	you say: to be
# veiteding	a add
# auderury	yet
#
# 	the partret's felt and york.
#
# quintum gentleph	i level in the thief of his crown to the
# Epoch 37/60
# 1780907/1780907 [==============================] - 58s 32us/step - loss: 1.3292 - acc: 0.5837
#
# ----- Generating text after Epoch: 36
# ----- Generating with seed: "l title and the seat
# 	of england's true-"
# l title and the seat
# 	of england's true-report his sword, roses,
# 	thus barn by, and coment.
# 	now sweet hermiration may never rate.
#
# gower	come!
# 	that belied, i'll have thusband to teilt
# 	here, that should see my man, good suffolk:
# 	and yet
# Epoch 38/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3290 - acc: 0.5834
#
# ----- Generating text after Epoch: 37
# ----- Generating with seed: "	come, come, you are well understood to "
# 	come, come, you are well understood to not.
#
# isabella	sir, to go about you for us is: since he are breathe me.
# 	shall i ask thee? i am sorry. we daught a by surgoed
# charber	sing upon been conjurer
# 	words in heaven: must be gone, i am a rig
# Epoch 39/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3281 - acc: 0.5838
#
# ----- Generating text after Epoch: 38
# ----- Generating with seed: "ng that he is forsworn:
# 	he calls us reb"
# ng that he is forsworn:
# 	he calls us rebutted both, and be tob
# 	we beseech your mac, to be loved thy forest weaper,
# 	he ceteed by my book of earth to proceed, ha,
# 	and give it i sayine. for and what's my fair?
# 	she is thus: who, where i sho
# Epoch 40/60
# 1780907/1780907 [==============================] - 58s 32us/step - loss: 1.3271 - acc: 0.5842
#
# ----- Generating text after Epoch: 39
# ----- Generating with seed: "s admittance; oft it doth; yea, and make"
# s admittance; oft it doth; yea, and makes his very power;
# 	one said,--  by happis, who brave frough,
# 	and show, and. kindness, and as it catrains
# 	with the reface. i am a great on so goes
# 	corrupting by my till and come are: say it sport,
#
# Epoch 41/60
# 1780907/1780907 [==============================] - 58s 32us/step - loss: 1.3267 - acc: 0.5841
#
# ----- Generating text after Epoch: 40
# ----- Generating with seed: " prince of tyre, and thou must kill him:"
#  prince of tyre, and thou must kill him:
# 	an ears, and thinking him the freshest intuny's money.
#
# 	[enter ventigh woman and is like bangs oursents.
# 	for some moossiquant clough man cause;
# 	and gloriance, still beloved continent,
# 	for the su
# Epoch 42/60
# 1780907/1780907 [==============================] - 58s 32us/step - loss: 1.3267 - acc: 0.5839
#
# ----- Generating text after Epoch: 41
# ----- Generating with seed: "t or fear.
#
# prince edward	methinks a wom"
# t or fear.
#
# prince edward	methinks a woman; our evening, must be dist bord
# 	the visithers--
#
# raven	say i long'd york,
# i pray the worth with such rome that
# 	is the man at becausions; and hath it
# 	mortimes.
#
# richard
# of love	the day' thank, th
# Epoch 43/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3257 - acc: 0.5842
#
# ----- Generating text after Epoch: 42
# ----- Generating with seed: "
# 	an arm? no: or take away the grief of "
#
# 	an arm? no: or take away the grief of her his
# 	oxford's army.
#
# king henry ci	well, quoth sorry fresh with wombs: if it say!
#
# gloucester	o, where night. the king's givencler'd adomences,
# 	a luputed cause once and croembury in the gravessis
# Epoch 44/60
# 1780907/1780907 [==============================] - 58s 32us/step - loss: 1.3246 - acc: 0.5845
#
# ----- Generating text after Epoch: 43
# ----- Generating with seed: "e painter's art.
# for through the painter"
# e painter's art.
# for through the painter]
#
# 	[exeunt]
#
#
#
#
# 	amward
#
#
# act v
#
#
#
#
# scene v	alonown wars unless never,
# 	if a dwor, and, it doth befa, tot sepabades
# 	by our fast singer! to the villain and his tempt!
# 	air reversal, close wet hours f
# Epoch 45/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3243 - acc: 0.5846
#
# ----- Generating text after Epoch: 44
# ----- Generating with seed: "gilia,
# 	valeria, &c. passing over the st"
# gilia,
# 	valeria, &c. passing over the striness
# 	arguments. my own kingness against heart,
# 	from himself, who is a cares that we strange citizen?
#
# falstaff	i have true strange else.
#
#
# post	sip: go, fear do thy sorrows for carrica!
# 	i	dose kn
# Epoch 46/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3236 - acc: 0.5850
#
# ----- Generating text after Epoch: 45
# ----- Generating with seed: ";
# 	and so success of mischief shall be b"
# ;
# 	and so success of mischief shall be be sudden you?
# 	o, let my kinsman: father, why, who ado:
# 	unwill say, nor it that, where you accesse
# 	this, or peruch, thou beseed; who warrant
# 	the brother beloved of this.
#
# first malber	away, nothing
# Epoch 47/60
# 1780907/1780907 [==============================] - 58s 32us/step - loss: 1.3226 - acc: 0.5853
#
# ----- Generating text after Epoch: 46
# ----- Generating with seed: " redoubted pembroke, sir james blunt,
# 	a"
#  redoubted pembroke, sir james blunt,
# 	and had to subjects the repelle of death,
# pence would leave the time will churchs the nozen has love at
# 	me neigh him out of these threater hall feed
# 	a particularies and the modes resamon,
#   like even
# Epoch 48/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3222 - acc: 0.5852
#
# ----- Generating text after Epoch: 47
# ----- Generating with seed: "ase me with speaking to me, thou
# 	mights"
# ase me with speaking to me, thou
# 	mights from slow of that you corrury! to thee full,
# 	and deep dicking his own state of her slendon,
# 	less call and preisor'd your lord care are a boot.
#
# 	[exeunt all is a since medice, like thou custest:
# 	i
# Epoch 49/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3216 - acc: 0.5854
#
# ----- Generating text after Epoch: 48
# ----- Generating with seed: " say,
# 	one that takes upon him to be a d"
#  say,
# 	one that takes upon him to be a dead
# 	to bectors., tolking
# 	a mysext still be wit them.' if canst wend? pray you,
# 	cousin.
#
# second lord	i may i prison,
# 	in greatness, or called with to my still of your andrance,
# 	to safe, as back the
# Epoch 50/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3212 - acc: 0.5853
#
# ----- Generating text after Epoch: 49
# ----- Generating with seed: "re go you
# 	with bats and clubs? the matt"
# re go you
# 	with bats and clubs? the matter now are i
# 	have unlaspped his fool. go to and bid their lives.
# 	alas, ye nothing was a puck to chance!
# 	as it is breast.
#
# damentus	both, sir,         is a cunning to place!
# 	but comprace the state,
# Epoch 51/60
# 1780907/1780907 [==============================] - 58s 33us/step - loss: 1.3205 - acc: 0.5856
#
# ----- Generating text after Epoch: 50
# ----- Generating with seed: " riot and dishonour stain the brow
# 	of m"
#  riot and dishonour stain the brow
# 	of minut and soldiers even with it. go,
# 	and hereof windomed hereon would distrebs
# 	to titilegrance so heart: these fellows faiger,
# 	is the grief return of the good
# vious mean'd and take with so. let a go
# Epoch 52/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3202 - acc: 0.5859
#
# ----- Generating text after Epoch: 51
# ----- Generating with seed: "r martyr'd signs;
# 	she says she drinks n"
# r martyr'd signs;
# 	she says she drinks nemulr those thoughts;
# and up your clear.
#
# both wine is one nobediles of ours you stay,
# 	when my men among you come of leapy, air.
# 	prisoners, can estaring to quantitoo, when
# 	his hat: shall but we do
# Epoch 53/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3198 - acc: 0.5860
#
# ----- Generating text after Epoch: 52
# ----- Generating with seed: "fellow handles his bow like a
# 	crow-keep"
# fellow handles his bow like a
# 	crow-keeping, or in gremio, and love is
# 	for me, more-sall us strange thing and you that' it,
# 	where is oyster in them into this pay to
# 	made dedire no lendity from him in case.
#
#
# suffolk	you, far it now? sulv
# Epoch 54/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3193 - acc: 0.5860
#
# ----- Generating text after Epoch: 53
# ----- Generating with seed: "r bills?
#
# cade	marry, presently.
#
# all	o,"
# r bills?
#
# cade	marry, presently.
#
# all	o, you went prosper, beating in the fool.
#
# petruchio	frait me, my urgoinia, momenture, my very prockeed,
# 	and gotries swore.
#
# mistress quickly	heaven is no chanting in accondmamitius,
# and will die advic
# Epoch 55/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3190 - acc: 0.5858
#
# ----- Generating text after Epoch: 54
# ----- Generating with seed: "ds thou hast in ephesus;
# 	beg thou, or b"
# ds thou hast in ephesus;
# 	beg thou, or bidence, and told his own lords.
#
# baudlet	sufficient and shall passion of thieves and
# 	men and bowels of by queen! here's are now good
# when you see her pure other conscience,
# 	and. trully the fore to c
# Epoch 56/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3184 - acc: 0.5860
#
# ----- Generating text after Epoch: 55
# ----- Generating with seed: "ce	your good-worship is welcome.
#
# falsta"
# ce	your good-worship is welcome.
#
# falstaff	kiss the mo to the in the devil with a heaven:
# 	this thing, as latest, you that, when sweet love
# 	lay a mortip'd lucius: to call thee door,
# 	from bless in attendance, as thine eye	then men presentl
# Epoch 57/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3181 - acc: 0.5861
#
# ----- Generating text after Epoch: 56
# ----- Generating with seed: "so far
# 	officious; for i am proof agains"
# so far
# 	officious; for i am proof against my false
# 	noble a picture of the fire to cheek turn
# a put poesertal by to be hands on death.
# 	humphrey, write them for them, remain me
# 	i am murder'd at some steble thee that,
# 	who hath rubly messub
# Epoch 58/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3179 - acc: 0.5863
#
# ----- Generating text after Epoch: 57
# ----- Generating with seed: "
#
# mistress ford	but is my husband coming"
#
#
# mistress ford	but is my husband coming not, for with a troops;
# 	full of doth duke on postiance he were so.
#
# desdemona	i throrsten on my counterfeit:
# 	nor is combing been are dead unto so;
# 	poor heart. gofodned me to stole you myseegness.
#
# Epoch 59/60
# 1780907/1780907 [==============================] - 57s 32us/step - loss: 1.3175 - acc: 0.5863
#
# ----- Generating text after Epoch: 58
# ----- Generating with seed: "rs. were my worth greater, my duty would"
# rs. were my worth greater, my duty would stell;
# 	and he that is terrme through the chapply
# 	easy thy apperish and brief; if it comes so?
# 	in the gildly is not life for my five knave.
#
# 	[floughtso cressida, xin us glad fortune,
# 	i plaid not
# Epoch 60/60
# 1780907/1780907 [==============================] - 58s 33us/step - loss: 1.3167 - acc: 0.5868
#
# ----- Generating text after Epoch: 59
# ----- Generating with seed: "use.
#
# king richard ii	now put it, god, i"
# use.
#
# king richard ii	now put it, god, if it be divining fight,
# 	should be breath in a coke and for so thought,
# 	and committed thee in court of citizen
# 	old 'at untiede: a peace; he will do know,
# 	so the sun was through the toy been french

# %%
start_index = random.randint(0, len(text) - maxlen - 1)

for diversity in [0.2, 0.5, 1, 1.2]:
    print()
    print('----t = %f----' % diversity)
    generated = ''
    sentence = text[start_index: start_index + maxlen]
    generated += sentence
    print('----- Generating with seed: "' + sentence + '"')
    print(generated)

    for i in range(400):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()
# Out:
# ----t = 0.200000----
# ----- Generating with seed: "gh flame, and
# 	through ford and whirlipo"
# gh flame, and
# 	through ford and whirlipo
# rs of the strings.
# /opt/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: RuntimeWarning: divide by zero encountered in log
# 	thou hast married the court of the strength
# 	and this that i shall be so the devil.
#
# 	[enter a gentleman]
#
# 	why, thou art the suppose of the court and the strength
# 	to the court of the strange of the strings,
# 	and the strings and should be so things to the
# 	force, the brother of the prince of the stranger
# 	the strength and the strings of the love
# 	that i will be the strings of
#
# ----t = 0.500000----
# ----- Generating with seed: "gh flame, and
# 	through ford and whirlipo"
# gh flame, and
# 	through ford and whirlipo
# us souls be a company
# 	to mercy and therefore the king conceived,
# 	and the store of her thing shall be my sport.
#
# 	[enter a cousin]
#
# 	and i cannot be sent the earth, the part
# 	is to the strange of a wit to the devil,
# 	and stand the sent of the stranger to the world.
# 	the strength and a say the sea of the world.
#
# lord anconero	the part, and then be warrant and again.
#
# 	[enter sir john of donm call
#
# ----t = 1.000000----
# ----- Generating with seed: "gh flame, and
# 	through ford and whirlipo"
# gh flame, and
# 	through ford and whirlipo
# red, from a huncine eye.
#
# boyecy	well to be extremement shall break a bond.
# 	and let me just, me what lie with ruth;
# 	i love my an impriren grows and seech.
#
# 'shame particular some secret never for the
# 	vaux. shall we you offer you? plain than this?
# 	but how not but scancy: say air and be cymitation:
# 	ho, ross.
#
# messenger	father cassains his totbliny, end, night to brew
# 	to vanishments, preter, pe
#
# ----t = 1.200000----
# ----- Generating with seed: "gh flame, and
# 	through ford and whirlipo"
# gh flame, and
# 	through ford and whirlipo
# ring over-hooling
# 	one to welcome elven.
# 	but yet a smort's drowst, unlewver'd, for thee,
# 	more looks, thou'rt hear haive his altaful
# 	or mainble clepry, welcome; if my pholios gone
# 	thinh thoughts two dwel, do't, trankard and
# 	run my smell-burning flow;
# 	this dorse valour.
#
# marria	ha! venter'd, somehoymest i am, that my sairious less
# 	alva sapoit. hark. the shrink theeds abrow's riffest stuffflib

# %%
model.save('model_lm.dat')
