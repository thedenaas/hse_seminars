# %% [markdown]
# # Web Mining

# %% [markdown]
# ### Installation notes
#
# You will need some OS Linux distribution to complete that task. If you do not have linux, at least install it on your virtual machine. Anyway, linux-based OS will save you lots of time in future in that course.
#
#
#
# sudo apt-get install libmysqlclient-dev
# git clone -b python3 https://github.com/clips/pattern
# cd pattern
# python setup.py install

# %% [markdown]
# Relevant documentation can be found https://www.clips.uantwerpen.be/pages/pattern-web#wikipedia

# %%
from pattern.web import Wikipedia, plaintext


article = Wikipedia().article('Rwandan_Civil_War')
for section in article.sections:
    print(' ' * section.level + section.title)
    print(plaintext(section.source))
    break
# Out:
# Rwandan Civil War
# This article is about the 1990–1994 civil war. For the social revolution of 1959–1962, see Rwandan Revolution. For the 1994 genocide, see Rwandan genocide.
#
# Rwandan Civil War
#
# Map of Rwanda with towns and roads
#
# Date
# 1 October 1990 − 18 July 1994
#
# (3 years, 9 months, 2 weeks and 4 days)
# Location
# Rwanda
# Result
#
# Rwandan Patriotic Front victory
#
# * Arusha Accords signed
# * End of the Rwandan genocide
#
# Belligerents
#
# Rwandan Patriotic Front (RPF)  Rwandan Armed Forces (FAR)
#
# Zaire (1990–1991)
#
# France (until 1994) Interahamwe
#
# Impuzamugambi
# Commanders and leaders
#
# Fred Rwigyema †
#
# Paul Kagame  Juvénal Habyarimana †
#
# Théoneste Bagosora
#
# Augustin Bizimungu
# Strength
#
# 20,000 RPF[1] 35,000 FAR[1]
# Casualties and losses
#
# 5,000 killed 5,000 killed
#
# ...

# %% [markdown]
# Links to other wiki articles

# %%
article.links
# Out:
# ['Rwanda',
#  'Index of Rwanda-related articles',
#  'History of Rwanda',
#  'Geography of Rwanda',
#  'Administrative divisions of Rwanda',
#  'Politics of Rwanda',
#  'Governance of Rwanda',
#  'Government of Rwanda',
#  'Military of Rwanda',
#  'Economy of Rwanda',
#  'Infrastructure of Rwanda',
#  'Transport in Rwanda',
#  'Demographics of Rwanda',
#  'Religion in Rwanda',
#  'National symbols of Rwanda',
#  'Symbols of Rwanda',
#  'Outline of Rwanda',
#  'Bibliography of Rwanda',
#  'France',
#  "1973 Rwandan coup d'état",
#  '1994 Bophuthatswana crisis',
#  '2007–08 Kenyan crisis',
#  '2013 Guinea clashes',
#  'Addis Ababa',
#  'Agathe Habyarimana',
#  'Aid',
#  'Akagera National Park',
#  'Akazu',
#  'Algerian Civil War',
#  'Allied Democratic Forces insurgency',
#  'Angolan Civil War',
#  'Ankole',
#  'Arab Spring',
#  'Arab Winter',
#  'Arusha',
#  'Arusha Accords',
#  'Arusha International Conference Centre',
#  'Arusha accords',
# ...
